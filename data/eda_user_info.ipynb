# %%
from matplotlib_venn import venn3, venn3_circles
import matplotlib.pyplot as plt
import sweetviz as sv
import pandas as pd
import numpy as np
import json
import os

# %%
# Opening JSON file
with open('raw/user_info.json') as json_file:
    data = json.load(json_file)

# %% [markdown]
# # Record Count

# %%
user_profile_df = pd.DataFrame(data)
user_profile_df
# Out:
#                                              user_id language
# 0                        1035438645_0001a990e1204539     [bn]
# 1                        1035438645_00614e127baf5032      NaN
# 2                        1035438645_0085cccaab2be238      NaN
# 3                        1035438645_008be4469bb4fd3e     [hi]
# 4                        1035438645_00911e06fff46358     [kn]
# ...                                              ...      ...
# 9947  u.browser.for.lite.uc.browser_c01e190db6718708      NaN
# 9948  u.browser.for.lite.uc.browser_d80d95cde4777ad7      NaN
# 9949  u.browser.for.lite.uc.browser_e204aa1960a5427b      NaN
# 9950  u.browser.for.lite.uc.browser_efa957ae19d0a012      NaN
# 9951  u.browser.for.lite.uc.browser_f40249a9525621bc      NaN
#
# [9952 rows x 2 columns]

# %% [markdown]
# # Unique Users Count

# %%
print(user_profile_df['user_id'].isnull().values.any())
len(user_profile_df['user_id'].unique())
# Out:
# False
# 9952

# %% [markdown]
# # Missing Count in Languages

# %%
print(user_profile_df['language'].isnull().values.any())
print(user_profile_df['language'].isnull().sum())
# Out:
# True
# 5546

# %% [markdown]
# # Language Values Distribution
#
# ![language_dist.png](attachment:language_dist.png)

# %%
user_profile_expanded = user_profile_df.explode('language')
report = sv.analyze(user_profile_expanded)
report.show_html()
# Out:
# ...
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # INSPECTING THE TOP 3 MOST FREQUENT LANGUAGES

# %% [markdown]
# # Filtering out users that view "hi" content

# %%
hi_users = user_profile_expanded[user_profile_expanded['language']=="hi"]['user_id'].tolist()
hi_users
# Out:
# ['1035438645_008be4469bb4fd3e',
#  '1035438645_02dad3f85ab5e34d',
#  '1035438645_03b8b004f55b9d5e',
#  '1035438645_045a3f9d773150ce',
#  '1035438645_05df685ac21ec33d',
#  '1035438645_08ee4f2a3b795759',
#  '1035438645_0cd359a30ecfffec',
#  '1035438645_0e8ada36bf98b958',
#  '1035438645_0f1563aed0d587f9',
#  '1035438645_11990fc3e329302b',
#  '1035438645_13c0c5fd2f8b2832',
#  '1035438645_14f720ca9e99a69e',
#  '1035438645_15df98e3552117ec',
#  '1035438645_1735f3638d358d45',
#  '1035438645_17bf2bfdfeb0ee47',
#  '1035438645_17e6193e9dc6faa8',
#  '1035438645_186a6fd483f1e3d5',
#  '1035438645_18ec8c3ddc0d7770',
#  '1035438645_195d3c22db4336ec',
#  '1035438645_1c939687eab92223',
#  '1035438645_1cf1a4bfca40e5b1',
#  '1035438645_1d4bfb534dd47c47',
#  '1035438645_1d739d7f12d0ade7',
#  '1035438645_1e451a981754140f',
#  '1035438645_1ef079dbd90a6903',
#  '1035438645_208897bceeeed320',
#  '1035438645_21c5e6d9f68b531a',
#  '1035438645_235b3d85ca04844d',
#  '1035438645_268e09be9155eb9f',
# ...

# %% [markdown]
# # Language Distribution among "hi" users
#
# ![hi_vs_rest.png](attachment:hi_vs_rest.png)

# %%
hi_users_df = user_profile_df[user_profile_df['user_id'].isin(hi_users)].reset_index(drop=True)
hi_users_expanded = hi_users_df.explode('language')
report = sv.analyze(hi_users_expanded)
report.show_html()
# Out:
# ...
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Filtering out users that view "mr" content

# %%
mr_users = user_profile_expanded[user_profile_expanded['language']=="mr"]['user_id'].tolist()
mr_users
# Out:
# ['1035438645_10e3b5772327346f',
#  '1035438645_21c5e6d9f68b531a',
#  '1035438645_22128c0345d832af',
#  '1035438645_29bbf20c5036cda7',
#  '1035438645_2c569d5fccc30d5e',
#  '1035438645_2e8931fd809d988e',
#  '1035438645_362f8937805a66ba',
#  '1035438645_3c482bbc72daf133',
#  '1035438645_3cf378afd7c24735',
#  '1035438645_3dc850a3f41ba347',
#  '1035438645_3ecd7bb0d33b766e',
#  '1035438645_40f8022211c4e033',
#  '1035438645_42f96b1ef6daa674',
#  '1035438645_4ac8edec6c91f52b',
#  '1035438645_4ede26a03a513690',
#  '1035438645_4f2502392f15afdf',
#  '1035438645_50ae3586b730c47d',
#  '1035438645_50c2ff1d67c01fb1',
#  '1035438645_54657914d90c3201',
#  '1035438645_548fd40edd7e9828',
#  '1035438645_56b841e3d11e4465',
#  '1035438645_596f443cf6bc729a',
#  '1035438645_5be69e56d9753ad6',
#  '1035438645_5d4df99cb8deeffd',
#  '1035438645_687db6ccb05a7cfb',
#  '1035438645_68ec5c25350c7f94',
#  '1035438645_713a20bd355822d7',
#  '1035438645_7656c324b2ff1a58',
#  '1035438645_7c2de04210b8e773',
# ...

# %% [markdown]
# # Language Distribution among "mr" users
#
# ![mr_vs_rest.png](attachment:mr_vs_rest.png)

# %%
mr_users_df = user_profile_df[user_profile_df['user_id'].isin(mr_users)].reset_index(drop=True)
mr_users_expanded = mr_users_df.explode('language')
report = sv.analyze(mr_users_expanded)
report.show_html()
# Out:
# ...
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Filtering out users that view "en" content

# %%
en_users = user_profile_expanded[user_profile_expanded['language']=="en"]['user_id'].tolist()
en_users
# Out:
# ['1035438645_21c5e6d9f68b531a',
#  '1035438645_2a55d38a18504198',
#  '1035438645_3d486fc37c22b24a',
#  '1035438645_42f96b1ef6daa674',
#  '1035438645_4ac8edec6c91f52b',
#  '1035438645_7561d46ad1f38044',
#  '1035438645_7bf8cb38d773a2f7',
#  '1035438645_8f1a52e97e770fb8',
#  '1035438645_ab928c1cda0283f6',
#  '1035438645_b0e52f8375fb7579',
#  '1035438645_d51aba33648355dd',
#  '1035438645_d7ca20e146b34b50',
#  '1035438645_f57740ff5ad27e72',
#  '1042879543_11c994a77c3fed7f',
#  '1042879543_12f02585105d709a',
#  '1042879543_3010a3c1ab859035',
#  '1042879543_5328d91058050902',
#  '1042879543_57a2e91a02cb03d3',
#  '1042879543_a9cd67c034c062a2',
#  '1042879543_ad876a735e26bc65',
#  '1186255453_a51306a0a4336ae0',
#  '1186255453_fdb44bcfc87fdd68',
#  '1455925592_04f4549cb405f0d8',
#  '1455925592_1d862eb9088932b1',
#  '1455925592_371d07926a5becdb',
#  '1455925592_39531671fe1a05b1',
#  '1455925592_4a1f16f653d7528e',
#  '1455925592_6279f4ca64afb883',
#  '1455925592_cb4e6154954f8040',
# ...

# %% [markdown]
# # Language Distribution among "en" users
#
# ![en_vs_rest.png](attachment:en_vs_rest.png)

# %%
en_users_df = user_profile_df[user_profile_df['user_id'].isin(en_users)].reset_index(drop=True)
en_users_expanded = en_users_df.explode('language')
report = sv.analyze(en_users_expanded)
report.show_html()
# Out:
# ...
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Obtaining users from the rest of the languages

# %%
te_users = user_profile_expanded[user_profile_expanded['language']=="te"]['user_id'].tolist()
ta_users = user_profile_expanded[user_profile_expanded['language']=="ta"]['user_id'].tolist()
bn_users = user_profile_expanded[user_profile_expanded['language']=="bn"]['user_id'].tolist()
gu_users = user_profile_expanded[user_profile_expanded['language']=="gu"]['user_id'].tolist()
kn_users = user_profile_expanded[user_profile_expanded['language']=="kn"]['user_id'].tolist()
ml_users = user_profile_expanded[user_profile_expanded['language']=="ml"]['user_id'].tolist()
rest_users = user_profile_expanded[user_profile_expanded['language']==""]['user_id'].tolist()

# %%
def view_overlap(d1,d2,d3,l1,l2,l3):
    venn3(
         [set(d1), set(d2), set(d3)],
         set_colors=('#3E64AF', '#3EAF5D', '#D74E3B'), 
         set_labels = (l1, l2, l3),
         alpha=0.75
)
    venn3_circles([set(d1), set(d2), set(d3)], lw=0.7)
    plt.show()

# %%
view_overlap(d1=hi_users, d2=mr_users, d3=en_users, l1="hi", l2="mr", l3="en")

# %%
index_labels = {
    0:"hi",
    1:"mr",
    2:"en",
    3:"te",
    4:"ta",
    5:"bn",
    6:"gu",
    7:"kn",
    8:"ml",
    9:"<empty>"
}

all_users = [set(hi_users), set(mr_users),
             set(en_users), set(te_users),
             set(ta_users), set(bn_users),
             set(gu_users), set(kn_users),
             set(ml_users), set(rest_users)]
             
for index in range(len(all_users)):
    print(f"Size of {index_labels[index]} = {len(all_users[index])}")
    for inner_index in range(index+1, len(all_users)):
        print(f"---Size of {index_labels[inner_index]} = {len(all_users[inner_index])}")
        print(f"-----Intersection Size between {index_labels[index]} and {index_labels[inner_index]} = {len(all_users[index].intersection(all_users[inner_index]))}")
# Out:
# Size of hi = 2000
# ---Size of mr = 546
# -----Intersection Size between hi and mr = 128
# ---Size of en = 528
# -----Intersection Size between hi and en = 181
# ---Size of te = 491
# -----Intersection Size between hi and te = 113
# ---Size of ta = 446
# -----Intersection Size between hi and ta = 115
# ---Size of bn = 432
# -----Intersection Size between hi and bn = 125
# ---Size of gu = 411
# -----Intersection Size between hi and gu = 124
# ---Size of kn = 372
# -----Intersection Size between hi and kn = 121
# ---Size of ml = 253
# -----Intersection Size between hi and ml = 120
# ---Size of <empty> = 64
# -----Intersection Size between hi and <empty> = 0
# Size of mr = 546
# ---Size of en = 528
# -----Intersection Size between mr and en = 122
# ---Size of te = 491
# -----Intersection Size between mr and te = 107
# ---Size of ta = 446
# -----Intersection Size between mr and ta = 111
# ---Size of bn = 432
# -----Intersection Size between mr and bn = 118
# ---Size of gu = 411
# ...

# %%
user_profile_expanded.to_pickle("user_info_expanded.pkl")
